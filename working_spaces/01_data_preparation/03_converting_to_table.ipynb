# %% [markdown]
# # Converting JSON data into a tabular, ball-by-ball format

# %%
import pandas as pd
import json
import os
from datetime import datetime
import copy

# %%
def load_data_from_json(filepath):
    dict_format = json.loads(open(filepath, "r").read())
    return dict_format

# %%
class MatchSituation:
    def __init__(self, match, delivery=None, init=False, previous_delivery = None, format=50):
        self.previous_delivery = previous_delivery
        self.next_delivery = None
        self.parent = match

        if init:
            self.bowlers = {
                x: {"balls_remaining": 6*format/5, "finished_spell": False, "at_crease": False, "wickets": 0, "runs": 0} for x in match.team1_players
            }
            self.batters = {
                x: {"at_crease": False, "on_strike": False, "dismissed": False, "runs": 0, "balls": 0} for x in match.team2_players
            }
            self.runs_remaining = match.match['target']['runs']
            self.wickets_remaining = 10
            self.balls_remaining = 6*format
            self.current_runs = 0
            self.current_wickets = 0
            self.current_balls = 0
            self.extras_count = 0
            self.batter_on_strike = None
            self.bowler_on_strike = None
            self.batter_off_strike = None
            self.runs = 0
        else:
            previous_delivery.next_delivery = self
            self.bowlers = copy.deepcopy(previous_delivery.bowlers)
            self.batters = copy.deepcopy(previous_delivery.batters)
            self.runs_remaining = copy.deepcopy(previous_delivery.runs_remaining)
            self.wickets_remaining = copy.deepcopy(previous_delivery.wickets_remaining)
            self.balls_remaining = copy.deepcopy(previous_delivery.balls_remaining)
            self.current_runs = copy.deepcopy(previous_delivery.current_runs)
            self.current_wickets = copy.deepcopy(previous_delivery.current_wickets)
            self.current_balls = copy.deepcopy(previous_delivery.current_balls)
            self.extras_count = copy.deepcopy(previous_delivery.extras_count)
            self.batter_on_strike = copy.deepcopy(previous_delivery.batter_on_strike)
            self.batter_off_strike = copy.deepcopy(previous_delivery.batter_off_strike)
            self.bowler_on_strike = copy.deepcopy(previous_delivery.bowler_on_strike)
            self.update(delivery)
        
    def update(self, delivery):
        # print(delivery)
        
        self.batters[delivery['batter']]['at_crease'] = True
        self.batters[delivery['batter']]['on_strike'] = True
        self.batter_on_strike = delivery['batter']
        self.batter_off_strike = delivery['non_striker']
        self.batters[delivery['non_striker']]['at_crease'] = True
        self.batters[delivery['non_striker']]['on_strike'] = False
        
        self.batters[delivery['batter']]['runs'] += delivery['runs']['batter']
        self.current_runs += delivery['runs']['total']
        self.runs_remaining -= delivery['runs']['total']

        self.runs = delivery['runs']['total']

        self.extras_count += delivery['runs']['extras']

        if (('extras' in delivery) and ('wides' in delivery['extras'] or 'noballs' in delivery['extras'])) or ('extras' not in delivery):
            self.bowlers[delivery['bowler']]['runs'] += delivery['runs']['total']

        if (('extras' in delivery) and ('wides' in delivery['extras'])) == False:

            self.batters[delivery['batter']]['balls'] += 1

            if (('extras' in delivery) and ('noballs' in delivery['extras'])) == False:

                self.bowlers[delivery['bowler']]['balls_remaining'] -= 1
                self.bowlers[delivery['bowler']]['at_crease'] = True
                self.bowler_on_strike = delivery['bowler']
                self.balls_remaining -= 1
                self.current_balls += 1

            if self.bowlers[delivery['bowler']]['balls_remaining'] % 6 == 0:
                self.bowlers[delivery['bowler']]['at_crease'] = False

            if self.bowlers[delivery['bowler']]['balls_remaining'] == 0:
                self.bowlers[delivery['bowler']]['finished_spell'] = True
        
        if 'wickets' in delivery:
            self.wickets_remaining -= 1
            self.current_wickets += 1

            self.batters[delivery['wickets'][0]['player_out']]['dismissed'] = True
            self.batters[delivery['wickets'][0]['player_out']]['on_strike'] = False
            self.batters[delivery['wickets'][0]['player_out']]['at_crease'] = False
            if delivery['wickets'][0]['kind'] in ['caught', "bowled", "lbw", "stumped"]:
                self.bowlers[delivery['bowler']]['wickets'] += 1

        

class OneDayMatch:
    def __init__(self, match_dict, matchno=None):
        self.match_date = datetime.strptime(match_dict['info']['dates'][0], "%Y-%m-%d")
        self.team1 = match_dict['innings'][0]['team']
        self.team2 = match_dict['innings'][1]['team']
        self.toss_winner = match_dict['info']['toss']['winner']
        self.ground = match_dict['info']['venue']
        self.team1_players = match_dict['info']['players'][self.team1]
        self.team2_players = match_dict['info']['players'][self.team2]
        self.match = match_dict['innings'][1]
        self.winner = match_dict['info']['outcome']['winner']
        self.matchno = matchno
        self.ball_by_ball = [MatchSituation(self, format=50, init=True)]
        self.process_match()
    
    def process_match(self):
        prev_delivery = self.ball_by_ball[-1]
        for over in self.match['overs']:
            for delivery in over['deliveries']:
                    prev_delivery = MatchSituation(self, delivery=delivery, previous_delivery=prev_delivery)

# %%
def dump(obj):
    result = {}
    for attr in dir(obj):
      if attr.startswith("__") == False:
        result[attr] = getattr(obj, attr)
    return result

domestic_loc = '../../data/step_02/domestic/'
domestic_matches = []

os.makedirs("../../data/step_03/matches/", exist_ok=True)
domestic_matches_file = "../../data/step_03/matches_domestic.csv"

open(domestic_matches_file, "w").close()

for filename in [x for x in os.listdir(domestic_loc) if x.endswith('.json')]:
  match_file = "../../data/step_03/matches/%s.csv" % filename[:-5]
  open(domestic_matches_file, "w").close()
  match_dict = load_data_from_json(domestic_loc + filename)
  match = OneDayMatch(match_dict, matchno=filename)
  match_dict = dump(match)
  for team in ['team1', 'team2']:
    player_count = 1
    for player in match_dict[team+'_players']:
      match_dict[team+'_player_%d' % player_count] = player
      player_count += 1
  drop_keys = ['ball_by_ball', 'match', 'update', 'process_match', 'team1_players', 'team2_players']
  for key in drop_keys:
    match_dict.pop(key, None)
  match_df = pd.DataFrame(match_dict, index=[0])
  match_df.to_csv(domestic_matches_file, mode='a', index=False, header=False)
  delivery = match.ball_by_ball[0].next_delivery
  while True:
      delivery_dict = dump(delivery)
      try:
        delivery_dict['batter_on_strike'] = delivery_dict['batters'][delivery_dict['batter_on_strike']]
      except KeyError:
        print(delivery_dict)
        break
      delivery_dict['batter_off_strike'] = delivery_dict['batters'][delivery_dict['batter_off_strike']]
      delivery_dict['bowler_on_strike'] = delivery_dict['bowlers'][delivery_dict['bowler_on_strike']]
      keys_to_drop = ['update', 'previous_delivery', 'parent', 'next_delivery', 'batters', 'bowlers']
      for key in list(delivery_dict.keys()):
          if key in keys_to_drop:
              delivery_dict.pop(key, None)
              continue
          if type(delivery_dict[key]) == dict:
              for key2 in delivery_dict[key].keys():
                  delivery_dict[key+"_"+key2] = delivery_dict[key][key2]
              delivery_dict.pop(key, None)
      round_2_keys_to_drop = ['batter_off_strike_at_crease', 'batter_off_strike_on_strike', 'batter_on_strike_at_crease', 'batter_on_strike_on_strike', 'bowler_on_strike_at_crease', 'bowler_on_strike_finished_spell']
      for key in list(delivery_dict.keys()):
          if key in round_2_keys_to_drop:
              delivery_dict.pop(key, None)
        
      delivery_df = pd.DataFrame(delivery_dict, index=[0])
      delivery_df.to_csv(match_file, mode='a', index=False, header=False)

      try:
          delivery = delivery.next_delivery
      except KeyError:
          break

international_loc = '../../data/step_02/international/'
international_matches = []

os.makedirs("../../data/step_03", exist_ok=True)
international_matches_file = "../../data/step_03/matches_international.csv"

open(international_matches_file, "w").close()

for filename in [x for x in os.listdir(international_loc) if x.endswith('.json')]:
  try:
    match_dict = load_data_from_json(international_loc + filename)
    match = OneDayMatch(match_dict, matchno=filename)
    match_dict = dump(match)
    for team in ['team1', 'team2']:
      player_count = 1
      for player in match_dict[team+'_players']:
        match_dict[team+'_player_%d' % player_count] = player
        player_count += 1
    drop_keys = ['ball_by_ball', 'match', 'update', 'process_match', 'team1_players', 'team2_players']
    for key in drop_keys:
      match_dict.pop(key, None)
    match_df = pd.DataFrame(match_dict, index=[0])
    match_df.to_csv(international_matches_file, mode='a', index=False, header=False)
  except KeyError as e:
    continue
# Out:
# {}
# {}
# {}
# {}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb Cell 5 line 4
#      <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>   break
#      <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a> delivery_dict['batter_off_strike'] = delivery_dict['batters'][delivery_dict['batter_off_strike']]
# ---> <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a> delivery_dict['bowler_on_strike'] = delivery_dict['bowlers'][delivery_dict['bowler_on_strike']]
#      <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> keys_to_drop = ['update', 'previous_delivery', 'parent', 'next_delivery', 'batters', 'bowlers']
#      <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> for key in list(delivery_dict.keys()):
#
# KeyError: None

# %%
delivery = match.ball_by_ball[0].next_delivery

while True:
    delivery_dict = dump(delivery)
    print(delivery_dict)
    delivery_dict['batter_on_strike'] = delivery_dict['batters'][delivery_dict['batter_on_strike']]
    delivery_dict['batter_off_strike'] = delivery_dict['batters'][delivery_dict['batter_off_strike']]
    delivery_dict['bowler_on_strike'] = delivery_dict['bowlers'][delivery_dict['bowler_on_strike']]
    keys_to_drop = ['update', 'previous_delivery', 'parent', 'next_delivery', 'batters', 'bowlers']
    for key in list(delivery_dict.keys()):
        if key in keys_to_drop:
            delivery_dict.pop(key, None)
            continue
        if type(delivery_dict[key]) == dict:
            for key2 in delivery_dict[key].keys():
                delivery_dict[key+"_"+key2] = delivery_dict[key][key2]
            delivery_dict.pop(key, None)
    round_2_keys_to_drop = ['batter_off_strike_at_crease', 'batter_off_strike_on_strike', 'batter_on_strike_at_crease', 'batter_on_strike_on_strike', 'bowler_on_strike_at_crease', 'bowler_on_strike_finished_spell']
    for key in list(delivery_dict.keys()):
        if key in round_2_keys_to_drop:
            delivery_dict.pop(key, None)

    try:
        delivery = delivery.next_delivery
    except KeyError:
        break

delivery_dict
# Out:
# {'balls_remaining': 299, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 0, 'balls': 1}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 59.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 0}}, 'current_balls': 1, 'current_runs': 0, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d350610>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d3838d0>, 'runs': 0, 'runs_remaining': 303, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d383d90>>, 'wickets_remaining': 10}
# {'balls_remaining': 298, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 0, 'balls': 2}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 58.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 0}}, 'current_balls': 2, 'current_runs': 0, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d350c50>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d383d90>, 'runs': 0, 'runs_remaining': 303, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d350610>>, 'wickets_remaining': 10}
# {'balls_remaining': 297, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 1, 'balls': 3}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 57.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 1}}, 'current_balls': 3, 'current_runs': 1, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d351290>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d350610>, 'runs': 1, 'runs_remaining': 302, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d350c50>>, 'wickets_remaining': 10}
# {'balls_remaining': 296, 'batter_off_strike': 'ME Trescothick', 'batter_on_strike': 'NRD Compton', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 3}, 'NRD Compton': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 1, 'balls': 1}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 56.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 2}}, 'current_balls': 4, 'current_runs': 2, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d3518d0>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d350c50>, 'runs': 1, 'runs_remaining': 301, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d351290>>, 'wickets_remaining': 10}
# {'balls_remaining': 295, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 2, 'balls': 4}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 1}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 55.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 3}}, 'current_balls': 5, 'current_runs': 3, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d351f10>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d351290>, 'runs': 1, 'runs_remaining': 300, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d3518d0>>, 'wickets_remaining': 10}
# {'balls_remaining': 294, 'batter_off_strike': 'ME Trescothick', 'batter_on_strike': 'NRD Compton', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 2, 'balls': 4}, 'NRD Compton': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 6, 'current_runs': 3, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d352550>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d3518d0>, 'runs': 0, 'runs_remaining': 300, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d351f10>>, 'wickets_remaining': 10}
# {'balls_remaining': 293, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 2, 'balls': 5}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'GG Wagg', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 59.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 7, 'current_runs': 3, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d352b90>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d351f10>, 'runs': 0, 'runs_remaining': 300, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d352550>>, 'wickets_remaining': 10}
# {'balls_remaining': 292, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 2, 'balls': 6}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'GG Wagg', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 58.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 8, 'current_runs': 3, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d353350>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d352550>, 'runs': 0, 'runs_remaining': 300, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d352b90>>, 'wickets_remaining': 10}
# {'balls_remaining': 291, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 2, 'balls': 7}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'GG Wagg', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 57.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 9, 'current_runs': 3, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d353990>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d352b90>, 'runs': 0, 'runs_remaining': 300, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d353350>>, 'wickets_remaining': 10}
# {'balls_remaining': 290, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 2, 'balls': 8}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'GG Wagg', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 56.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 0}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 10, 'current_runs': 3, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d353fd0>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d353350>, 'runs': 0, 'runs_remaining': 300, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d353990>>, 'wickets_remaining': 10}
# {'balls_remaining': 289, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 6, 'balls': 9}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'GG Wagg', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 55.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 4}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 11, 'current_runs': 7, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d33c650>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d353990>, 'runs': 4, 'runs_remaining': 296, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d353fd0>>, 'wickets_remaining': 10}
# {'balls_remaining': 288, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 7, 'balls': 10}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'GG Wagg', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 5}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 3}}, 'current_balls': 12, 'current_runs': 8, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d33cc90>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d353fd0>, 'runs': 1, 'runs_remaining': 295, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d33c650>>, 'wickets_remaining': 10}
# {'balls_remaining': 287, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 7, 'balls': 11}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 5}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 53.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 3}}, 'current_balls': 13, 'current_runs': 8, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d33d2d0>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d33c650>, 'runs': 0, 'runs_remaining': 295, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d33cc90>>, 'wickets_remaining': 10}
# {'balls_remaining': 286, 'batter_off_strike': 'NRD Compton', 'batter_on_strike': 'ME Trescothick', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 8, 'balls': 12}, 'NRD Compton': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 1, 'balls': 2}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 5}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 52.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 4}}, 'current_balls': 14, 'current_runs': 9, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d33d910>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d33cc90>, 'runs': 1, 'runs_remaining': 294, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d33d2d0>>, 'wickets_remaining': 10}
# {'balls_remaining': 285, 'batter_off_strike': 'ME Trescothick', 'batter_on_strike': 'NRD Compton', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 8, 'balls': 12}, 'NRD Compton': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 1, 'balls': 3}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 5}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 51.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 4}}, 'current_balls': 15, 'current_runs': 9, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d33df50>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d33d2d0>, 'runs': 0, 'runs_remaining': 294, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d33d910>>, 'wickets_remaining': 10}
# {'balls_remaining': 284, 'batter_off_strike': 'ME Trescothick', 'batter_on_strike': 'NRD Compton', 'batters': {'ME Trescothick': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 8, 'balls': 12}, 'NRD Compton': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 1, 'balls': 4}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'TD Groenewald': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': False, 'runs': 0, 'balls': 0}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 54.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 5}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'DA Cosker': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MG Hogan': {'balls_remaining': 50.0, 'finished_spell': False, 'at_crease': True, 'wickets': 0, 'runs': 4}}, 'current_balls': 16, 'current_runs': 9, 'current_wickets': 0, 'extras_count': 0, 'next_delivery': <__main__.MatchSituation object at 0x7f390d33e590>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d33d910>, 'runs': 0, 'runs_remaining': 294, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d33df50>>, 'wickets_remaining': 10}
# ...
# {'balls_remaining': 62, 'batter_off_strike': 'TD Groenewald', 'batter_on_strike': 'MJ Leach', 'batters': {'ME Trescothick': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 25, 'balls': 26}, 'NRD Compton': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 9, 'balls': 18}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 45, 'balls': 60}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 10, 'balls': 23}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 3, 'balls': 7}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 23, 'balls': 33}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 7, 'balls': 8}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 24, 'balls': 27}, 'TD Groenewald': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 32, 'balls': 26}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 13, 'balls': 8}, 'MJ Leach': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 0, 'balls': 3}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 1, 'runs': 39}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 18.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 47}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 42}, 'DA Cosker': {'balls_remaining': 6.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 50}, 'MG Hogan': {'balls_remaining': 14.0, 'finished_spell': False, 'at_crease': True, 'wickets': 2, 'runs': 18}}, 'current_balls': 238, 'current_runs': 206, 'current_wickets': 9, 'extras_count': 15, 'next_delivery': <__main__.MatchSituation object at 0x7f390d1efb90>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d1eef10>, 'runs': 0, 'runs_remaining': 97, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d1ef550>>, 'wickets_remaining': 1}
# {'balls_remaining': 62, 'batter_off_strike': 'TD Groenewald', 'batter_on_strike': 'MJ Leach', 'batters': {'ME Trescothick': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 25, 'balls': 26}, 'NRD Compton': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 9, 'balls': 18}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 45, 'balls': 60}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 10, 'balls': 23}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 3, 'balls': 7}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 23, 'balls': 33}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 7, 'balls': 8}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 24, 'balls': 27}, 'TD Groenewald': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 32, 'balls': 26}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 13, 'balls': 8}, 'MJ Leach': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 0, 'balls': 3}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 1, 'runs': 39}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 18.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 47}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 42}, 'DA Cosker': {'balls_remaining': 6.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 50}, 'MG Hogan': {'balls_remaining': 14.0, 'finished_spell': False, 'at_crease': True, 'wickets': 2, 'runs': 19}}, 'current_balls': 238, 'current_runs': 207, 'current_wickets': 9, 'extras_count': 16, 'next_delivery': <__main__.MatchSituation object at 0x7f390d1cc210>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d1ef550>, 'runs': 1, 'runs_remaining': 96, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d1efb90>>, 'wickets_remaining': 1}
# {'balls_remaining': 61, 'batter_off_strike': 'TD Groenewald', 'batter_on_strike': 'MJ Leach', 'batters': {'ME Trescothick': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 25, 'balls': 26}, 'NRD Compton': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 9, 'balls': 18}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 45, 'balls': 60}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 10, 'balls': 23}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 3, 'balls': 7}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 23, 'balls': 33}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 7, 'balls': 8}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 24, 'balls': 27}, 'TD Groenewald': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 32, 'balls': 26}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 13, 'balls': 8}, 'MJ Leach': {'at_crease': True, 'on_strike': True, 'dismissed': False, 'runs': 0, 'balls': 4}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 1, 'runs': 39}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 18.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 47}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 42}, 'DA Cosker': {'balls_remaining': 6.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 50}, 'MG Hogan': {'balls_remaining': 13.0, 'finished_spell': False, 'at_crease': True, 'wickets': 2, 'runs': 19}}, 'current_balls': 239, 'current_runs': 207, 'current_wickets': 9, 'extras_count': 16, 'next_delivery': <__main__.MatchSituation object at 0x7f390d1cc850>, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d1efb90>, 'runs': 0, 'runs_remaining': 96, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d1cc210>>, 'wickets_remaining': 1}
# {'balls_remaining': 60, 'batter_off_strike': 'TD Groenewald', 'batter_on_strike': 'MJ Leach', 'batters': {'ME Trescothick': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 25, 'balls': 26}, 'NRD Compton': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 9, 'balls': 18}, 'PD Trego': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 45, 'balls': 60}, 'CA Ingram': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 10, 'balls': 23}, 'JC Hildreth': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 3, 'balls': 7}, 'AWR Barrow': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 23, 'balls': 33}, 'L Gregory': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 7, 'balls': 8}, 'JG Myburgh': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 24, 'balls': 27}, 'TD Groenewald': {'at_crease': True, 'on_strike': False, 'dismissed': False, 'runs': 32, 'balls': 26}, 'AC Thomas': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 13, 'balls': 8}, 'MJ Leach': {'at_crease': False, 'on_strike': False, 'dismissed': True, 'runs': 0, 'balls': 5}}, 'bowler_on_strike': 'MG Hogan', 'bowlers': {'JA Rudolph': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'J Allenby': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 1, 'runs': 39}, 'WD Bragg': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'MW Goodwin': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'CB Cooke': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'GG Wagg': {'balls_remaining': 18.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 47}, 'MA Wallace': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'AG Salter': {'balls_remaining': 60.0, 'finished_spell': False, 'at_crease': False, 'wickets': 0, 'runs': 0}, 'JAR Harris': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 42}, 'DA Cosker': {'balls_remaining': 6.0, 'finished_spell': False, 'at_crease': False, 'wickets': 2, 'runs': 50}, 'MG Hogan': {'balls_remaining': 12.0, 'finished_spell': False, 'at_crease': False, 'wickets': 3, 'runs': 19}}, 'current_balls': 240, 'current_runs': 207, 'current_wickets': 10, 'extras_count': 16, 'next_delivery': None, 'parent': <__main__.OneDayMatch object at 0x7f390d383a10>, 'previous_delivery': <__main__.MatchSituation object at 0x7f390d1cc210>, 'runs': 0, 'runs_remaining': 96, 'update': <bound method MatchSituation.update of <__main__.MatchSituation object at 0x7f390d1cc850>>, 'wickets_remaining': 0}
# {}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb Cell 6 line 6
#       <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> delivery_dict = dump(delivery)
#       <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(delivery_dict)
# ----> <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> delivery_dict['batter_on_strike'] = delivery_dict['batters'][delivery_dict['batter_on_strike']]
#       <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> delivery_dict['batter_off_strike'] = delivery_dict['batters'][delivery_dict['batter_off_strike']]
#       <a href='vscode-notebook-cell://drvmeiqj5lnrrbi.studio.ap-southeast-2.sagemaker.aws/home/sagemaker-user/talking_cricket/working_spaces/01_data_preparation/03_converting_to_table.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> delivery_dict['bowler_on_strike'] = delivery_dict['bowlers'][delivery_dict['bowler_on_strike']]
#
# KeyError: 'batters'
